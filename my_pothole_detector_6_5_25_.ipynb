# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishRJ/pothole_detection/blob/main/my_pothole_detector_6_5_25_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.4 MB/s eta 0:00:00
# ...

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
import pickle
from ultralytics import YOLO

# Load a pretrained model (if you haven't trained one yet)
model = YOLO('yolov8n.pt')  # Or use the path to your custom trained model

# ... (Your model training or loading code) ...

# Save the model to a pickle file
with open('my_pothole_detector.pkl', 'wb') as f:
    pickle.dump(model, f)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f866fff-ff27-4d22-a62c-c27f56e834fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f866fff-ff27-4d22-a62c-c27f56e834fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.rename(list(uploaded.keys())[0], 'my_pothole_detector.pkl')

# %%
import pickle
from ultralytics import YOLO
from IPython.display import Image, display

# %%
with open('my_pothole_detector.pkl', 'rb') as f:
       loaded_model = pickle.load(f)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be716803-ea20-4772-b23a-623ef233f844" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be716803-ea20-4772-b23a-623ef233f844">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(uploaded.keys())[0]

# %%
results = loaded_model.predict(source=image_path, conf=0.25, save=True)
# Out:
# image 1/1 /content/lr_00009_bottom_right.jpg: 480x640 8 Longitudinal cracks, 2 Transverse cracks, 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict

# %%
result_path = f"runs/detect/predict/{image_path}"
display(Image(filename=result_path))

# %%
result_path = f"runs/detect/predict/{image_path}"
